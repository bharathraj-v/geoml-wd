# %%
import pandas as pd

data = pd.read_csv('metadata.csv')

# %%
data.describe()
# Out:
#        idInstallation    idInverter  countInverters      idArrays  \
# count    28408.000000  28408.000000    28408.000000  28408.000000
# mean     19079.681393   2855.602190        1.734723   4035.710574
# std      11217.226996   2078.621742       16.860343   1463.324133
# min          1.000000      0.000000        0.000000     51.000000
# 25%       9768.750000    594.000000        1.000000   3141.000000
# 50%      18447.500000   3289.000000        1.000000   3800.000000
# 75%      27773.250000   4238.000000        1.000000   5039.000000
# max      41071.000000   7357.000000     2800.000000   7405.000000
#
#         countArrays       surface       azimuth  typeInstallation  \
# count  28408.000000  2.840800e+04  28408.000000      28408.000000
# mean      22.811743  3.397397e+02     37.611377          0.770030
# std       64.102917  4.978444e+04    107.055657          0.837873
# min        0.000000  0.000000e+00   -180.000000          0.000000
# ...

# %%
data.head()
# Out:
#    idInstallation    identifiant  idInverter              nameInverter  \
# 0               1    OSIBG1RDEDJ         593      SMA - Sunny Boy 2800
# 1              10    VTIOIAEQJEC         601   SMA - Sunny Boy 4200 TL
# 2            1001  BWZEK3E9OJAOY         736  Sputnik - SOLARMAX 2000C
# 3            1002  FEIKQ3EAGKXFB         256           Fronius - IG 30
# 4            1003  NDXQX3EBUEZNO         591      SMA - Sunny Boy 2500
#
#    countInverters  idArrays                     nameArrays  countArrays  \
# 0               1      2120          Sanyo - HIP-215 NKHE1           14
# 1               1      2121          Sanyo - HIP-215 NKHE5           20
# 2               1      3110              Sunasol - SLMI140           15
# 3               1      2156  Schott - ASE-165-GT-FT/MC/170           18
# 4               1      1188   Biohaus - Biosol 180 P 50/6+           16
#
#    surface  azimuth  ...  tilt     kWp  departement                      city  \
# ...

# %%
data['city']
# Out:
# 0                Castanet-Tolosan
# 1        Saint-Barthélemy-d'Anjou
# 2                Décines-Charpieu
# 3                         Rousson
# 4              Andouillé-Neuville
#                    ...
# 28403                     Lorgies
# 28404                     Braives
# 28405                   Rixensart
# 28406                    Jodoigne
# 28407                       BREST
# Name: city, Length: 28408, dtype: object

# %%
cities_list = data['city'].unique()

# %%
len(cities_list)
# Out:
# 11615
